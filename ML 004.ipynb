# %% [markdown]
# ### Machine Learning - Data Distribution

# %% [markdown]
# #### In real world, the data sets are much bigger. To create big data sets for testing, we use the python module Numpy, which comes with a number of methods to create random data sets, of any size

# %%
import numpy

# %%
# Create an array containing 250 random floats between 0 and 5:

x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [4.94072908 2.76498505 3.34174582 3.84719682 4.86564669 2.65272396
#  4.66038094 3.12084799 4.56156464 1.31577155 1.35240787 1.91992392
#  4.64535705 2.22773612 0.73977531 3.1003163  3.14109466 1.90285822
#  2.92640499 2.71836667 0.61754605 2.75291272 0.58410851 1.04373545
#  2.60557713 4.17309422 1.95463998 2.41988769 2.27484945 2.70254299
#  3.70836375 1.24386575 4.09518642 4.7188217  3.994266   3.26934079
#  3.18234038 4.38296223 1.74137643 2.40095375 2.87563878 1.06556424
#  0.04248541 3.13958439 2.32167769 3.6406408  0.08102557 1.5358113
#  1.87324525 3.59623327 4.68444575 1.24642828 0.12862283 0.08604856
#  1.61150779 0.3717152  3.1654725  2.97506137 0.79025681 3.5235285
#  0.27410458 4.57591267 0.20410347 4.19491082 3.84363801 1.07405419
#  1.28776907 3.54301171 0.80915457 0.77540805 2.16488596 0.62868724
#  3.51757825 2.23890857 0.70476885 0.96040161 0.81747709 0.39325512
#  3.65230924 0.03368576 0.67695058 4.57461051 4.71587477 3.26066753
# ...

# %% [markdown]
# ### To Visualize the dataset

# %%
# Lets use Matplotlib module to draw a histogram.

# %%
import numpy
import matplotlib.pyplot as plt

# %%
x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %%
# Note: 250 values is not considered big. You can create a random set of values, and by changing the parameters.

# %%
# For example

import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 100000)

plt.hist(x, 100)
plt.show()

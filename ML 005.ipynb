# %% [markdown]
# ## Machine Learning - Noramal Data Distribution

# %% [markdown]
# #### A type of data distribution where the array is concentrated around a given value.

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()
